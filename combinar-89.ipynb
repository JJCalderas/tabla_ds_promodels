# %%
from EvoMSA.base import EvoMSA
from microtc.utils import load_model, save_model
from itertools import combinations
import random
import numpy as np
from glob import glob
from joblib import Parallel, delayed
import joblib as joblib
import pandas as pd
from sklearn import metrics
import winsound

import warnings
warnings.filterwarnings("ignore")

pd.set_option('display.max_colwidth', None)

winsound.Beep(3000, 900)

# %%
winsound.Beep(4500, 300)

# %%
stacked_method = "sklearn.svm.LinearSVC"

# 8 Models Pre-Trained EvoMSA
pre_models_dict = {
    "davincis22": [load_model('pre_models/davincis22_Es.evomsa'), stacked_method],
    "detoxis21_aggressiveness" : [load_model('pre_models/detoxis21_aggressiveness_Es.evomsa'), stacked_method],
    "exist21" : [load_model('pre_models/exist21_Es.evomsa'), stacked_method],
    "haha21" : [load_model('pre_models/haha21_Es.evomsa'), stacked_method],
    "meoffendes21" : [load_model('pre_models/meoffendes21_Es.evomsa'), stacked_method],
    "mexa3t18_aggress" : [load_model('pre_models/mexa3t18_aggress_Es.evomsa'), stacked_method],
    "misogyny_centrogeo" : [load_model('pre_models/misogyny_centrogeo_Es.evomsa'), stacked_method],
    "metwo22" : [load_model('pre_models/metwo22_Es.evomsa'), stacked_method]
}  

print(len(pre_models_dict.keys()), pre_models_dict.keys())
# Out:
# 8 dict_keys(['davincis22', 'detoxis21_aggressiveness', 'exist21', 'haha21', 'meoffendes21', 'mexa3t18_aggress', 'misogyny_centrogeo', 'metwo22'])

# %%
combinaciones = []
items = pre_models_dict.keys()
for i in range(1, len(items)):
    combs = combinations(items, i+1)
    n_c = sum(1 for e in combs)
    print(i, n_c, combs)
    combs = combinations(items, i+1)
    for c in combs:
        #print(c)
        combinaciones.append(c)
len(combinaciones)     ### 247 combinaciones de 2 a 8 elementos
# Out:
# 1 28 <itertools.combinations object at 0x00000167A99CE540>
# 2 56 <itertools.combinations object at 0x00000167A99CE540>
# 3 70 <itertools.combinations object at 0x00000167A99CE540>
# 4 56 <itertools.combinations object at 0x00000167A99CE540>
# 5 28 <itertools.combinations object at 0x00000167A99CE540>
# 6 8 <itertools.combinations object at 0x00000167A99CE540>
# 7 1 <itertools.combinations object at 0x00000167A99CE540>
# 247

# %%
# tomar random 60 
samples = random.sample(combinaciones, 53)

# agregar los single models para garantizar que existan    
for p in pre_models_dict:
    samples.append((p, np.nan))

# agegar conjunto vacio
samples.append(()) 

len(samples), samples
# Out:
# (62,
#  [('davincis22',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('davincis22', 'exist21', 'metwo22'),
#   ('detoxis21_aggressiveness',
#    'exist21',
#    'meoffendes21',
#    'misogyny_centrogeo'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'haha21',
#    'meoffendes21',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('exist21', 'haha21', 'meoffendes21', 'misogyny_centrogeo'),
#   ('davincis22', 'meoffendes21', 'mexa3t18_aggress', 'misogyny_centrogeo'),
#   ('davincis22', 'detoxis21_aggressiveness', 'misogyny_centrogeo', 'metwo22'),
#   ('detoxis21_aggressiveness', 'meoffendes21', 'misogyny_centrogeo'),
#   ('davincis22', 'exist21', 'haha21', 'mexa3t18_aggress'),
#   ('davincis22', 'exist21', 'meoffendes21', 'mexa3t18_aggress', 'metwo22'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'haha21',
#    'meoffendes21',
#    'mexa3t18_aggress'),
#   ('exist21', 'meoffendes21', 'misogyny_centrogeo', 'metwo22'),
#   ('davincis22', 'metwo22'),
#   ('detoxis21_aggressiveness', 'meoffendes21', 'mexa3t18_aggress', 'metwo22'),
#   ('davincis22', 'detoxis21_aggressiveness', 'meoffendes21', 'metwo22'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'haha21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo'),
#   ('davincis22', 'meoffendes21', 'misogyny_centrogeo'),
#   ('detoxis21_aggressiveness', 'meoffendes21', 'mexa3t18_aggress'),
#   ('haha21', 'meoffendes21', 'misogyny_centrogeo', 'metwo22'),
#   ('exist21', 'meoffendes21', 'mexa3t18_aggress'),
#   ('davincis22', 'detoxis21_aggressiveness', 'exist21', 'mexa3t18_aggress'),
#   ('meoffendes21', 'mexa3t18_aggress', 'metwo22'),
#   ('davincis22', 'detoxis21_aggressiveness', 'haha21', 'meoffendes21'),
#   ('detoxis21_aggressiveness', 'exist21', 'misogyny_centrogeo', 'metwo22'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'metwo22'),
#   ('exist21', 'haha21', 'meoffendes21', 'metwo22'),
#   ('exist21', 'haha21', 'meoffendes21'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'exist21',
#    'meoffendes21',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('exist21', 'misogyny_centrogeo', 'metwo22'),
#   ('detoxis21_aggressiveness',
#    'haha21',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('detoxis21_aggressiveness',
#    'exist21',
#    'haha21',
#    'meoffendes21',
#    'mexa3t18_aggress'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'meoffendes21',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('davincis22', 'exist21', 'misogyny_centrogeo', 'metwo22'),
#   ('detoxis21_aggressiveness', 'exist21', 'meoffendes21', 'metwo22'),
#   ('davincis22', 'exist21', 'meoffendes21', 'misogyny_centrogeo', 'metwo22'),
#   ('haha21', 'meoffendes21'),
#   ('meoffendes21', 'mexa3t18_aggress', 'misogyny_centrogeo', 'metwo22'),
#   ('detoxis21_aggressiveness',
#    'exist21',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo'),
#   ('exist21', 'misogyny_centrogeo'),
#   ('davincis22',
#    'exist21',
#    'haha21',
#    'meoffendes21',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('haha21', 'misogyny_centrogeo', 'metwo22'),
#   ('detoxis21_aggressiveness', 'exist21', 'haha21', 'meoffendes21'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'haha21',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo'),
#   ('detoxis21_aggressiveness',
#    'haha21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'exist21',
#    'haha21',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('davincis22', 'detoxis21_aggressiveness', 'exist21', 'metwo22'),
#   ('detoxis21_aggressiveness', 'exist21', 'haha21', 'mexa3t18_aggress'),
#   ('detoxis21_aggressiveness',
#    'exist21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'exist21',
#    'meoffendes21',
#    'misogyny_centrogeo'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'exist21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo'),
#   ('mexa3t18_aggress', 'metwo22'),
#   ('detoxis21_aggressiveness', 'exist21', 'meoffendes21', 'mexa3t18_aggress'),
#   ('davincis22', 'detoxis21_aggressiveness', 'exist21'),
#   ('davincis22', nan),
#   ('detoxis21_aggressiveness', nan),
#   ('exist21', nan),
#   ('haha21', nan),
#   ('meoffendes21', nan),
#   ('mexa3t18_aggress', nan),
#   ('misogyny_centrogeo', nan),
#   ('metwo22', nan),
#   ()])

# %%
df_samples =  pd.DataFrame(samples)
df_samples.to_csv('premodels_combinations_63.csv')

# %%
pd.set_option('display.max_colwidth', None)
pd.options.display.max_rows = 1200
df_samples
# Out:
#                            0                         1                   2  \
# 0                 davincis22              meoffendes21    mexa3t18_aggress
# 1                 davincis22                   exist21             metwo22
# 2   detoxis21_aggressiveness                   exist21        meoffendes21
# 3                 davincis22  detoxis21_aggressiveness              haha21
# 4                    exist21                    haha21        meoffendes21
# 5                 davincis22              meoffendes21    mexa3t18_aggress
# 6                 davincis22  detoxis21_aggressiveness  misogyny_centrogeo
# 7   detoxis21_aggressiveness              meoffendes21  misogyny_centrogeo
# 8                 davincis22                   exist21              haha21
# 9                 davincis22                   exist21        meoffendes21
# 10                davincis22  detoxis21_aggressiveness              haha21
# 11                   exist21              meoffendes21  misogyny_centrogeo
# 12                davincis22                   metwo22                None
# 13  detoxis21_aggressiveness              meoffendes21    mexa3t18_aggress
# 14                davincis22  detoxis21_aggressiveness        meoffendes21
# 15                davincis22  detoxis21_aggressiveness              haha21
# 16                davincis22              meoffendes21  misogyny_centrogeo
# 17  detoxis21_aggressiveness              meoffendes21    mexa3t18_aggress
# 18                    haha21              meoffendes21  misogyny_centrogeo
# 19                   exist21              meoffendes21    mexa3t18_aggress
# 20                davincis22  detoxis21_aggressiveness             exist21
# 21              meoffendes21          mexa3t18_aggress             metwo22
# 22                davincis22  detoxis21_aggressiveness              haha21
# 23  detoxis21_aggressiveness                   exist21  misogyny_centrogeo
# 24                davincis22  detoxis21_aggressiveness        meoffendes21
# 25                   exist21                    haha21        meoffendes21
# 26                   exist21                    haha21        meoffendes21
# 27                davincis22  detoxis21_aggressiveness             exist21
# 28                   exist21        misogyny_centrogeo             metwo22
# 29  detoxis21_aggressiveness                    haha21        meoffendes21
# 30  detoxis21_aggressiveness                   exist21              haha21
# 31                davincis22  detoxis21_aggressiveness        meoffendes21
# 32                davincis22                   exist21  misogyny_centrogeo
# 33  detoxis21_aggressiveness                   exist21        meoffendes21
# 34                davincis22                   exist21        meoffendes21
# 35                    haha21              meoffendes21                None
# 36              meoffendes21          mexa3t18_aggress  misogyny_centrogeo
# 37  detoxis21_aggressiveness                   exist21        meoffendes21
# 38                   exist21        misogyny_centrogeo                None
# 39                davincis22                   exist21              haha21
# 40                    haha21        misogyny_centrogeo             metwo22
# 41  detoxis21_aggressiveness                   exist21              haha21
# 42                davincis22  detoxis21_aggressiveness              haha21
# 43  detoxis21_aggressiveness                    haha21    mexa3t18_aggress
# 44                davincis22  detoxis21_aggressiveness             exist21
# 45                davincis22  detoxis21_aggressiveness             exist21
# 46  detoxis21_aggressiveness                   exist21              haha21
# 47  detoxis21_aggressiveness                   exist21    mexa3t18_aggress
# 48                davincis22  detoxis21_aggressiveness             exist21
# 49                davincis22  detoxis21_aggressiveness             exist21
# 50          mexa3t18_aggress                   metwo22                None
# 51  detoxis21_aggressiveness                   exist21        meoffendes21
# 52                davincis22  detoxis21_aggressiveness             exist21
# 53                davincis22                       NaN                None
# 54  detoxis21_aggressiveness                       NaN                None
# 55                   exist21                       NaN                None
# 56                    haha21                       NaN                None
# 57              meoffendes21                       NaN                None
# 58          mexa3t18_aggress                       NaN                None
# 59        misogyny_centrogeo                       NaN                None
# 60                   metwo22                       NaN                None
# 61                      None                      None                None
#
#                      3                   4                   5
# 0   misogyny_centrogeo             metwo22                None
# 1                 None                None                None
# 2   misogyny_centrogeo                None                None
# 3         meoffendes21  misogyny_centrogeo             metwo22
# 4   misogyny_centrogeo                None                None
# 5   misogyny_centrogeo                None                None
# 6              metwo22                None                None
# 7                 None                None                None
# 8     mexa3t18_aggress                None                None
# 9     mexa3t18_aggress             metwo22                None
# 10        meoffendes21    mexa3t18_aggress                None
# 11             metwo22                None                None
# 12                None                None                None
# 13             metwo22                None                None
# 14             metwo22                None                None
# 15    mexa3t18_aggress  misogyny_centrogeo                None
# 16                None                None                None
# 17                None                None                None
# 18             metwo22                None                None
# 19                None                None                None
# 20    mexa3t18_aggress                None                None
# 21                None                None                None
# 22        meoffendes21                None                None
# 23             metwo22                None                None
# 24    mexa3t18_aggress             metwo22                None
# 25             metwo22                None                None
# 26                None                None                None
# 27        meoffendes21  misogyny_centrogeo             metwo22
# 28                None                None                None
# 29    mexa3t18_aggress  misogyny_centrogeo             metwo22
# 30        meoffendes21    mexa3t18_aggress                None
# 31  misogyny_centrogeo             metwo22                None
# 32             metwo22                None                None
# 33             metwo22                None                None
# 34  misogyny_centrogeo             metwo22                None
# 35                None                None                None
# 36             metwo22                None                None
# 37    mexa3t18_aggress  misogyny_centrogeo                None
# 38                None                None                None
# 39        meoffendes21  misogyny_centrogeo             metwo22
# 40                None                None                None
# 41        meoffendes21                None                None
# 42        meoffendes21    mexa3t18_aggress  misogyny_centrogeo
# 43  misogyny_centrogeo                None                None
# 44              haha21  misogyny_centrogeo             metwo22
# 45             metwo22                None                None
# 46    mexa3t18_aggress                None                None
# 47  misogyny_centrogeo             metwo22                None
# 48        meoffendes21  misogyny_centrogeo                None
# 49    mexa3t18_aggress  misogyny_centrogeo                None
# 50                None                None                None
# 51    mexa3t18_aggress                None                None
# 52                None                None                None
# 53                None                None                None
# 54                None                None                None
# 55                None                None                None
# 56                None                None                None
# 57                None                None                None
# 58                None                None                None
# 59                None                None                None
# 60                None                None                None
# 61                None                None                None

# %%
# 17 Datasets
for i, fn in enumerate(glob("../dataset_es/*_Es_train.json")):
    train_df = pd.read_json(fn, lines=True)
    test_df = pd.read_json(fn.replace("_train", "_test"), lines=True)
    ds_n = fn.replace("..\\dataset_es\\",'').replace("../dataset_es\\",'').replace('_Es_train.json','')
    print(i, ds_n, train_df.shape, test_df.shape)
# Out:
# 0 davincis22 (2521, 2) (841, 2)
# 1 detoxis21_aggressiveness (2770, 2) (693, 2)
# 2 detoxis21_insult (2770, 2) (693, 2)
# 3 detoxis21_intolerance (2770, 2) (693, 2)
# 4 detoxis21_mockery (2770, 2) (693, 2)
# 5 detoxis21_sarcasm (2770, 2) (693, 2)
# 6 detoxis21_stereotype (2770, 2) (693, 2)
# 7 detoxis21_toxicity (2770, 2) (693, 2)
# 8 exist21 (2655, 2) (886, 2)
# 9 haha21 (18000, 2) (6000, 2)
# 10 meoffendes21 (3795, 2) (1265, 2)
# 11 metwo22 (2880, 2) (720, 2)
# 12 mexa3t18_aggress (5389, 5) (2311, 5)
# 13 misoginia (2645, 5) (662, 5)
# 14 misogyny_centrogeo (5752, 2) (1439, 2)
# 15 semeval2018_anger (1359, 6) (627, 6)
# 16 semeval2018_sadness (1350, 6) (641, 6)

# %%
# 17 Datasets
d = []
for i, fn in enumerate(glob("../dataset_es/*_Es_train.json")):
    train_df = pd.read_json(fn, lines=True)
    test_df = pd.read_json(fn.replace("_train", "_test"), lines=True)
    ds_n = fn.replace("..\\dataset_es\\",'').replace("../dataset_es\\",'').replace('_Es_train.json','')
    d.append({'dataset': ds_n, 'train_shape': train_df.shape, 'test_shape':test_df.shape})
df2 = pd.DataFrame(d)
df2.to_csv('dataset_shapes_17.csv')
df2
# Out:
#                      dataset train_shape test_shape
# 0                 davincis22   (2521, 2)   (841, 2)
# 1   detoxis21_aggressiveness   (2770, 2)   (693, 2)
# 2           detoxis21_insult   (2770, 2)   (693, 2)
# 3      detoxis21_intolerance   (2770, 2)   (693, 2)
# 4          detoxis21_mockery   (2770, 2)   (693, 2)
# 5          detoxis21_sarcasm   (2770, 2)   (693, 2)
# 6       detoxis21_stereotype   (2770, 2)   (693, 2)
# 7         detoxis21_toxicity   (2770, 2)   (693, 2)
# 8                    exist21   (2655, 2)   (886, 2)
# 9                     haha21  (18000, 2)  (6000, 2)
# 10              meoffendes21   (3795, 2)  (1265, 2)
# 11                   metwo22   (2880, 2)   (720, 2)
# 12          mexa3t18_aggress   (5389, 5)  (2311, 5)
# 13                 misoginia   (2645, 5)   (662, 5)
# 14        misogyny_centrogeo   (5752, 2)  (1439, 2)
# 15         semeval2018_anger   (1359, 6)   (627, 6)
# 16       semeval2018_sadness   (1350, 6)   (641, 6)

# %% [markdown]
# ---
