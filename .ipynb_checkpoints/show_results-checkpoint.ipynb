# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.options.display.max_rows = 2000
df = pd.read_csv('results_full_89.csv')

import warnings
warnings.filterwarnings("ignore")

# %%
# Mostrar todos los DataSets probados. Son 17.
df.dataset.unique()
# Out:
# array(['davincis22', 'detoxis21_aggressiveness', 'detoxis21_insult',
#        'detoxis21_intolerance', 'detoxis21_mockery', 'detoxis21_sarcasm',
#        'detoxis21_stereotype', 'detoxis21_toxicity', 'exist21', 'haha21',
#        'meoffendes21', 'metwo22', 'mexa3t18_aggress', 'misoginia',
#        'misogyny_centrogeo', 'semeval2018_anger', 'semeval2018_sadness'],
#       dtype=object)

# %%
len(df.dataset.unique())
# Out:
# 17

# %%
df.size
# Out:
# 22695

# %%
df.head()
# Out:
#    Unnamed: 0     dataset  combina_1 train.shape test.shape        f1  \
# 0           0  davincis22          0   (2521, 2)   (841, 2)  0.770816
# 1           1  davincis22          1   (2521, 2)   (841, 2)  0.769563
# 2           2  davincis22          2   (2521, 2)   (841, 2)  0.772169
# 3           3  davincis22          3   (2521, 2)   (841, 2)  0.774665
# 4           4  davincis22          4   (2521, 2)   (841, 2)  0.767473
#
#      recall  \
# 0  0.773789
# 1  0.775926
# 2  0.775641
# 3  0.779915
# 4  0.767949
#
#                                                               combinations  \
# 0                        ['exist21', 'meoffendes21', 'misogyny_centrogeo']
# 1    ['detoxis21_aggressiveness', 'exist21', 'haha21', 'mexa3t18_aggress']
# 2                                                     ['mexa3t18_aggress']
# 3                                               ['haha21', 'meoffendes21']
# 4  ['detoxis21_aggressiveness', 'haha21', 'misogyny_centrogeo', 'metwo22']
#
#    combina_2 train.shape.1      mean       std       min       max  \
# 0          0     (2521, 2)  0.758271  0.015197  0.739703  0.777660
# 1          1     (2521, 2)  0.760302  0.016210  0.739703  0.781493
# 2          2     (2521, 2)  0.758638  0.018294  0.735895  0.783409
# 3          3     (2521, 2)  0.760344  0.016187  0.739703  0.781124
# 4          4     (2521, 2)  0.757580  0.013925  0.739703  0.777660
#
#                                                                                            scores_kfold
# 0   [0.7497797841885048, 0.7397025171624714, 0.7492108102083143, 0.777660314369175, 0.7749999999999999]
# 1  [0.7497797841885048, 0.7397025171624714, 0.7534275997852157, 0.7814927510291749, 0.7771075456888892]
# 2  [0.7496695307336417, 0.7358951965065501, 0.7473101165085632, 0.7834086712930541, 0.7769084448910741]
# 3   [0.7517119583387416, 0.7397025171624714, 0.7515227659472955, 0.777660314369175, 0.7811236259467471]
# 4    [0.7539450521815667, 0.7397025171624714, 0.747515068623865, 0.777660314369175, 0.7690753851731735]

# %%
df_ = df.drop(df.columns[[0]],axis=1) # 15 son los 5 k-folds
df_.describe()

# Son 17 DataSets, 9 PreModels repartidos en 50 combinaciones/conjuntos de 3 a 7 elementos + conjunto vacio
# de la columna 0..6 corresponde al correr: train + predict + test 
# de la columna 7 en adelante es la validación cruzada solo con el train
# combinations: arreglo con los PreModels de EvoMSA usados en el training
# combina_1 y combina_2 son los índices del arreglo de PreModels. Es con lo que se enlaza el test y la validacíon cruzada
# en cada renglón, se excluye el PreModel que corresponde al Dataset que esta siendo probado

df_.head()
# Out:
#       dataset  combina_1 train.shape test.shape        f1    recall  \
# 0  davincis22          0   (2521, 2)   (841, 2)  0.770816  0.773789
# 1  davincis22          1   (2521, 2)   (841, 2)  0.769563  0.775926
# 2  davincis22          2   (2521, 2)   (841, 2)  0.772169  0.775641
# 3  davincis22          3   (2521, 2)   (841, 2)  0.774665  0.779915
# 4  davincis22          4   (2521, 2)   (841, 2)  0.767473  0.767949
#
#                                                               combinations  \
# 0                        ['exist21', 'meoffendes21', 'misogyny_centrogeo']
# 1    ['detoxis21_aggressiveness', 'exist21', 'haha21', 'mexa3t18_aggress']
# 2                                                     ['mexa3t18_aggress']
# 3                                               ['haha21', 'meoffendes21']
# 4  ['detoxis21_aggressiveness', 'haha21', 'misogyny_centrogeo', 'metwo22']
#
#    combina_2 train.shape.1      mean       std       min       max  \
# 0          0     (2521, 2)  0.758271  0.015197  0.739703  0.777660
# 1          1     (2521, 2)  0.760302  0.016210  0.739703  0.781493
# 2          2     (2521, 2)  0.758638  0.018294  0.735895  0.783409
# 3          3     (2521, 2)  0.760344  0.016187  0.739703  0.781124
# 4          4     (2521, 2)  0.757580  0.013925  0.739703  0.777660
#
#                                                                                            scores_kfold
# 0   [0.7497797841885048, 0.7397025171624714, 0.7492108102083143, 0.777660314369175, 0.7749999999999999]
# 1  [0.7497797841885048, 0.7397025171624714, 0.7534275997852157, 0.7814927510291749, 0.7771075456888892]
# 2  [0.7496695307336417, 0.7358951965065501, 0.7473101165085632, 0.7834086712930541, 0.7769084448910741]
# 3   [0.7517119583387416, 0.7397025171624714, 0.7515227659472955, 0.777660314369175, 0.7811236259467471]
# 4    [0.7539450521815667, 0.7397025171624714, 0.747515068623865, 0.777660314369175, 0.7690753851731735]

# %%
# df_.loc[df['dataset'] == 'meoffendes21'].sort_values(by=['f1'], ascending=False)

# %%
ds_final = pd.DataFrame()
df_.rename(columns = {'mean':'media', 'max':'maximo', 'min':'minimo'}, inplace = True)

# %%
_ = df_.loc[df['dataset'] == 'davincis22'].sort_values(by=['f1'], ascending=False)
empty_f1 = _.loc[_['combina_1'] == 50].f1.iat[0]
empty_media = _.loc[_['combina_1'] == 50].media.iat[0]
#empty_maximo = _.loc[_['combina_1'] == 50].maximo.iat[0]
dse = _.loc[(_['f1'] > empty_f1) | (_['combina_1'] == 50)]    
dse['diff_f1'] = dse.apply(lambda row: row.f1 - empty_f1, axis=1) 
dse['diff_media'] = dse.apply(lambda row: row.media - empty_media, axis=1) 
#dse['diff_maximo'] = dse.apply(lambda row: row.maximo - empty_maximo, axis=1) 
dse.style.background_gradient(cmap ='coolwarm', subset=['diff_f1', 'diff_media'])
# Out:
# <style type="text/css">
# #T_f2efa_row0_col14, #T_f2efa_row0_col15, #T_f2efa_row1_col14, #T_f2efa_row1_col15 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f2efa_row2_col14 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_f2efa_row2_col15, #T_f2efa_row3_col14 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f2efa_row3_col15 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# </style>
# <table id="T_f2efa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2efa_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_f2efa_level0_col1" class="col_heading level0 col1" >combina_1</th>
#       <th id="T_f2efa_level0_col2" class="col_heading level0 col2" >train.shape</th>
#       <th id="T_f2efa_level0_col3" class="col_heading level0 col3" >test.shape</th>
#       <th id="T_f2efa_level0_col4" class="col_heading level0 col4" >f1</th>
#       <th id="T_f2efa_level0_col5" class="col_heading level0 col5" >recall</th>
#       <th id="T_f2efa_level0_col6" class="col_heading level0 col6" >combinations</th>
#       <th id="T_f2efa_level0_col7" class="col_heading level0 col7" >combina_2</th>
#       <th id="T_f2efa_level0_col8" class="col_heading level0 col8" >train.shape.1</th>
#       <th id="T_f2efa_level0_col9" class="col_heading level0 col9" >media</th>
#       <th id="T_f2efa_level0_col10" class="col_heading level0 col10" >std</th>
#       <th id="T_f2efa_level0_col11" class="col_heading level0 col11" >minimo</th>
#       <th id="T_f2efa_level0_col12" class="col_heading level0 col12" >maximo</th>
#       <th id="T_f2efa_level0_col13" class="col_heading level0 col13" >scores_kfold</th>
#       <th id="T_f2efa_level0_col14" class="col_heading level0 col14" >diff_f1</th>
#       <th id="T_f2efa_level0_col15" class="col_heading level0 col15" >diff_media</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2efa_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_f2efa_row0_col0" class="data row0 col0" >davincis22</td>
#       <td id="T_f2efa_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_f2efa_row0_col2" class="data row0 col2" >(2521, 2)</td>
#       <td id="T_f2efa_row0_col3" class="data row0 col3" >(841, 2)</td>
#       <td id="T_f2efa_row0_col4" class="data row0 col4" >0.774665</td>
#       <td id="T_f2efa_row0_col5" class="data row0 col5" >0.779915</td>
#       <td id="T_f2efa_row0_col6" class="data row0 col6" >['haha21', 'meoffendes21']</td>
#       <td id="T_f2efa_row0_col7" class="data row0 col7" >3</td>
#       <td id="T_f2efa_row0_col8" class="data row0 col8" >(2521, 2)</td>
#       <td id="T_f2efa_row0_col9" class="data row0 col9" >0.760344</td>
#       <td id="T_f2efa_row0_col10" class="data row0 col10" >0.016187</td>
#       <td id="T_f2efa_row0_col11" class="data row0 col11" >0.739703</td>
#       <td id="T_f2efa_row0_col12" class="data row0 col12" >0.781124</td>
#       <td id="T_f2efa_row0_col13" class="data row0 col13" >[0.7517119583387416, 0.7397025171624714, 0.7515227659472955, 0.777660314369175, 0.7811236259467471]</td>
#       <td id="T_f2efa_row0_col14" class="data row0 col14" >0.001247</td>
#       <td id="T_f2efa_row0_col15" class="data row0 col15" >0.001236</td>
#     </tr>
#     <tr>
#       <th id="T_f2efa_level0_row1" class="row_heading level0 row1" >78</th>
#       <td id="T_f2efa_row1_col0" class="data row1 col0" >davincis22</td>
#       <td id="T_f2efa_row1_col1" class="data row1 col1" >78</td>
#       <td id="T_f2efa_row1_col2" class="data row1 col2" >(2521, 2)</td>
#       <td id="T_f2efa_row1_col3" class="data row1 col3" >(841, 2)</td>
#       <td id="T_f2efa_row1_col4" class="data row1 col4" >0.774665</td>
#       <td id="T_f2efa_row1_col5" class="data row1 col5" >0.779915</td>
#       <td id="T_f2efa_row1_col6" class="data row1 col6" >['haha21', 'meoffendes21']</td>
#       <td id="T_f2efa_row1_col7" class="data row1 col7" >78</td>
#       <td id="T_f2efa_row1_col8" class="data row1 col8" >(2521, 2)</td>
#       <td id="T_f2efa_row1_col9" class="data row1 col9" >0.760344</td>
#       <td id="T_f2efa_row1_col10" class="data row1 col10" >0.016187</td>
#       <td id="T_f2efa_row1_col11" class="data row1 col11" >0.739703</td>
#       <td id="T_f2efa_row1_col12" class="data row1 col12" >0.781124</td>
#       <td id="T_f2efa_row1_col13" class="data row1 col13" >[0.7517119583387416, 0.7397025171624714, 0.7515227659472955, 0.777660314369175, 0.7811236259467471]</td>
#       <td id="T_f2efa_row1_col14" class="data row1 col14" >0.001247</td>
#       <td id="T_f2efa_row1_col15" class="data row1 col15" >0.001236</td>
#     </tr>
#     <tr>
#       <th id="T_f2efa_level0_row2" class="row_heading level0 row2" >31</th>
#       <td id="T_f2efa_row2_col0" class="data row2 col0" >davincis22</td>
#       <td id="T_f2efa_row2_col1" class="data row2 col1" >31</td>
#       <td id="T_f2efa_row2_col2" class="data row2 col2" >(2521, 2)</td>
#       <td id="T_f2efa_row2_col3" class="data row2 col3" >(841, 2)</td>
#       <td id="T_f2efa_row2_col4" class="data row2 col4" >0.774567</td>
#       <td id="T_f2efa_row2_col5" class="data row2 col5" >0.768519</td>
#       <td id="T_f2efa_row2_col6" class="data row2 col6" >['detoxis21_aggressiveness', 'haha21', 'mexa3t18_aggress']</td>
#       <td id="T_f2efa_row2_col7" class="data row2 col7" >31</td>
#       <td id="T_f2efa_row2_col8" class="data row2 col8" >(2521, 2)</td>
#       <td id="T_f2efa_row2_col9" class="data row2 col9" >0.757934</td>
#       <td id="T_f2efa_row2_col10" class="data row2 col10" >0.016653</td>
#       <td id="T_f2efa_row2_col11" class="data row2 col11" >0.735698</td>
#       <td id="T_f2efa_row2_col12" class="data row2 col12" >0.783409</td>
#       <td id="T_f2efa_row2_col13" class="data row2 col13" >[0.7497797841885048, 0.7356979405034325, 0.7513210670401732, 0.7834086712930541, 0.7694648290674782]</td>
#       <td id="T_f2efa_row2_col14" class="data row2 col14" >0.001150</td>
#       <td id="T_f2efa_row2_col15" class="data row2 col15" >-0.001174</td>
#     </tr>
#     <tr>
#       <th id="T_f2efa_level0_row3" class="row_heading level0 row3" >50</th>
#       <td id="T_f2efa_row3_col0" class="data row3 col0" >davincis22</td>
#       <td id="T_f2efa_row3_col1" class="data row3 col1" >50</td>
#       <td id="T_f2efa_row3_col2" class="data row3 col2" >(2521, 2)</td>
#       <td id="T_f2efa_row3_col3" class="data row3 col3" >(841, 2)</td>
#       <td id="T_f2efa_row3_col4" class="data row3 col4" >0.773417</td>
#       <td id="T_f2efa_row3_col5" class="data row3 col5" >0.770370</td>
#       <td id="T_f2efa_row3_col6" class="data row3 col6" >['detoxis21_aggressiveness', 'haha21', 'meoffendes21', 'mexa3t18_aggress']</td>
#       <td id="T_f2efa_row3_col7" class="data row3 col7" >50</td>
#       <td id="T_f2efa_row3_col8" class="data row3 col8" >(2521, 2)</td>
#       <td id="T_f2efa_row3_col9" class="data row3 col9" >0.759109</td>
#       <td id="T_f2efa_row3_col10" class="data row3 col10" >0.015302</td>
#       <td id="T_f2efa_row3_col11" class="data row3 col11" >0.739703</td>
#       <td id="T_f2efa_row3_col12" class="data row3 col12" >0.781493</td>
#       <td id="T_f2efa_row3_col13" class="data row3 col13" >[0.7478464629308548, 0.7397025171624714, 0.7551254480286738, 0.7814927510291749, 0.7713758196982237]</td>
#       <td id="T_f2efa_row3_col14" class="data row3 col14" >0.000000</td>
#       <td id="T_f2efa_row3_col15" class="data row3 col15" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
corr = dse.corr()
corr.style.background_gradient(cmap ='coolwarm')
# Out:
# <style type="text/css">
# #T_a3388_row0_col0, #T_a3388_row0_col3, #T_a3388_row1_col1, #T_a3388_row1_col8, #T_a3388_row2_col2, #T_a3388_row3_col0, #T_a3388_row3_col3, #T_a3388_row4_col4, #T_a3388_row4_col9, #T_a3388_row5_col5, #T_a3388_row6_col6, #T_a3388_row7_col7, #T_a3388_row8_col1, #T_a3388_row8_col8, #T_a3388_row9_col4, #T_a3388_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a3388_row0_col1, #T_a3388_row0_col8, #T_a3388_row3_col1, #T_a3388_row3_col8 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_a3388_row0_col2, #T_a3388_row2_col5, #T_a3388_row3_col2 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_a3388_row0_col4, #T_a3388_row0_col9, #T_a3388_row3_col4, #T_a3388_row3_col9 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_a3388_row0_col5, #T_a3388_row3_col5 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_a3388_row0_col6, #T_a3388_row3_col6 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_a3388_row0_col7, #T_a3388_row3_col7 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_a3388_row1_col0, #T_a3388_row1_col3, #T_a3388_row8_col0, #T_a3388_row8_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_a3388_row1_col2, #T_a3388_row8_col2 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_a3388_row1_col4, #T_a3388_row1_col9, #T_a3388_row8_col4, #T_a3388_row8_col9 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_a3388_row1_col5, #T_a3388_row8_col5 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_a3388_row1_col6, #T_a3388_row8_col6 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_a3388_row1_col7, #T_a3388_row8_col7 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_a3388_row2_col0, #T_a3388_row2_col3 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_a3388_row2_col1, #T_a3388_row2_col8 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_a3388_row2_col4, #T_a3388_row2_col9, #T_a3388_row4_col2, #T_a3388_row9_col2 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_a3388_row2_col6 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_a3388_row2_col7 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_a3388_row4_col0, #T_a3388_row4_col3, #T_a3388_row4_col5, #T_a3388_row9_col0, #T_a3388_row9_col3, #T_a3388_row9_col5 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_a3388_row4_col1, #T_a3388_row4_col8, #T_a3388_row9_col1, #T_a3388_row9_col8 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_a3388_row4_col6, #T_a3388_row9_col6 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_a3388_row4_col7, #T_a3388_row9_col7 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_a3388_row5_col0, #T_a3388_row5_col3, #T_a3388_row6_col1, #T_a3388_row6_col5, #T_a3388_row6_col7, #T_a3388_row6_col8, #T_a3388_row7_col2, #T_a3388_row7_col4, #T_a3388_row7_col6, #T_a3388_row7_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a3388_row5_col1, #T_a3388_row5_col8 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_a3388_row5_col2 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_a3388_row5_col4, #T_a3388_row5_col9 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_a3388_row5_col6 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_a3388_row5_col7 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_a3388_row6_col0, #T_a3388_row6_col3 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_a3388_row6_col2 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_a3388_row6_col4, #T_a3388_row6_col9 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_a3388_row7_col0, #T_a3388_row7_col3 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_a3388_row7_col1, #T_a3388_row7_col8 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_a3388_row7_col5 {
#   background-color: #f6a283;
#   color: #000000;
# }
# </style>
# <table id="T_a3388">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3388_level0_col0" class="col_heading level0 col0" >combina_1</th>
#       <th id="T_a3388_level0_col1" class="col_heading level0 col1" >f1</th>
#       <th id="T_a3388_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_a3388_level0_col3" class="col_heading level0 col3" >combina_2</th>
#       <th id="T_a3388_level0_col4" class="col_heading level0 col4" >media</th>
#       <th id="T_a3388_level0_col5" class="col_heading level0 col5" >std</th>
#       <th id="T_a3388_level0_col6" class="col_heading level0 col6" >minimo</th>
#       <th id="T_a3388_level0_col7" class="col_heading level0 col7" >maximo</th>
#       <th id="T_a3388_level0_col8" class="col_heading level0 col8" >diff_f1</th>
#       <th id="T_a3388_level0_col9" class="col_heading level0 col9" >diff_media</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3388_level0_row0" class="row_heading level0 row0" >combina_1</th>
#       <td id="T_a3388_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a3388_row0_col1" class="data row0 col1" >-0.189221</td>
#       <td id="T_a3388_row0_col2" class="data row0 col2" >0.030476</td>
#       <td id="T_a3388_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_a3388_row0_col4" class="data row0 col4" >0.101797</td>
#       <td id="T_a3388_row0_col5" class="data row0 col5" >-0.239894</td>
#       <td id="T_a3388_row0_col6" class="data row0 col6" >0.200512</td>
#       <td id="T_a3388_row0_col7" class="data row0 col7" >-0.175431</td>
#       <td id="T_a3388_row0_col8" class="data row0 col8" >-0.189221</td>
#       <td id="T_a3388_row0_col9" class="data row0 col9" >0.101797</td>
#     </tr>
#     <tr>
#       <th id="T_a3388_level0_row1" class="row_heading level0 row1" >f1</th>
#       <td id="T_a3388_row1_col0" class="data row1 col0" >-0.189221</td>
#       <td id="T_a3388_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a3388_row1_col2" class="data row1 col2" >0.536866</td>
#       <td id="T_a3388_row1_col3" class="data row1 col3" >-0.189221</td>
#       <td id="T_a3388_row1_col4" class="data row1 col4" >0.260673</td>
#       <td id="T_a3388_row1_col5" class="data row1 col5" >0.889008</td>
#       <td id="T_a3388_row1_col6" class="data row1 col6" >-0.261116</td>
#       <td id="T_a3388_row1_col7" class="data row1 col7" >0.104389</td>
#       <td id="T_a3388_row1_col8" class="data row1 col8" >1.000000</td>
#       <td id="T_a3388_row1_col9" class="data row1 col9" >0.260673</td>
#     </tr>
#     <tr>
#       <th id="T_a3388_level0_row2" class="row_heading level0 row2" >recall</th>
#       <td id="T_a3388_row2_col0" class="data row2 col0" >0.030476</td>
#       <td id="T_a3388_row2_col1" class="data row2 col1" >0.536866</td>
#       <td id="T_a3388_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_a3388_row2_col3" class="data row2 col3" >0.030476</td>
#       <td id="T_a3388_row2_col4" class="data row2 col4" >0.954446</td>
#       <td id="T_a3388_row2_col5" class="data row2 col5" >0.090970</td>
#       <td id="T_a3388_row2_col6" class="data row2 col6" >0.674214</td>
#       <td id="T_a3388_row2_col7" class="data row2 col7" >-0.783016</td>
#       <td id="T_a3388_row2_col8" class="data row2 col8" >0.536866</td>
#       <td id="T_a3388_row2_col9" class="data row2 col9" >0.954446</td>
#     </tr>
#     <tr>
#       <th id="T_a3388_level0_row3" class="row_heading level0 row3" >combina_2</th>
#       <td id="T_a3388_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_a3388_row3_col1" class="data row3 col1" >-0.189221</td>
#       <td id="T_a3388_row3_col2" class="data row3 col2" >0.030476</td>
#       <td id="T_a3388_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_a3388_row3_col4" class="data row3 col4" >0.101797</td>
#       <td id="T_a3388_row3_col5" class="data row3 col5" >-0.239894</td>
#       <td id="T_a3388_row3_col6" class="data row3 col6" >0.200512</td>
#       <td id="T_a3388_row3_col7" class="data row3 col7" >-0.175431</td>
#       <td id="T_a3388_row3_col8" class="data row3 col8" >-0.189221</td>
#       <td id="T_a3388_row3_col9" class="data row3 col9" >0.101797</td>
#     </tr>
#     <tr>
#       <th id="T_a3388_level0_row4" class="row_heading level0 row4" >media</th>
#       <td i

# %%
for ds_n in df_.dataset.unique():
    _ = df_.loc[df_['dataset'] == ds_n].sort_values(by=['media'], ascending=False)
    empty_value = _.loc[_['combina_1'] == 50].media.iat[0]
    dse = _.loc[(_['media'] > empty_value) | (_['combina_1'] == 50)]    
    dse['diff'] = dse.apply(lambda row: row.media - empty_value, axis=1) 
    dse = dse.loc[dse['diff'] > 0.01]  
    ds_final = pd.concat([ds_final, dse], ignore_index=True)        
ds_final
# Out:
#                dataset  combina_1 train.shape test.shape        f1    recall  \
# 0  semeval2018_sadness         37   (1350, 6)   (641, 6)  0.441982  0.463427
# 1  semeval2018_sadness         29   (1350, 6)   (641, 6)  0.433939  0.472574
# 2  semeval2018_sadness         48   (1350, 6)   (641, 6)  0.445240  0.489352
# 3  semeval2018_sadness         21   (1350, 6)   (641, 6)  0.437775  0.478599
# 4  semeval2018_sadness         34   (1350, 6)   (641, 6)  0.436629  0.477404
# 5  semeval2018_sadness         47   (1350, 6)   (641, 6)  0.440377  0.454659
# 6  semeval2018_sadness         64   (1350, 6)   (641, 6)  0.438472  0.449538
# 7  semeval2018_sadness         73   (1350, 6)   (641, 6)  0.442313  0.462989
#
#                                                                                combinations  \
# 0    ['davincis22', 'detoxis21_aggressiveness', 'exist21', 'misogyny_centrogeo', 'metwo22']
# 1                ['davincis22', 'exist21', 'meoffendes21', 'misogyny_centrogeo', 'metwo22']
# 2                                           ['davincis22', 'misogyny_centrogeo', 'metwo22']
# 3                                                       ['davincis22', 'exist21', 'haha21']
# 4     ['davincis22', 'detoxis21_aggressiveness', 'exist21', 'haha21', 'misogyny_centrogeo']
# 5  ['davincis22', 'exist21', 'haha21', 'mexa3t18_aggress', 'misogyny_centrogeo', 'metwo22']
# 6                                   ['davincis22', 'haha21', 'mexa3t18_aggress', 'metwo22']
# 7                                      ['davincis22', 'exist21', 'meoffendes21', 'metwo22']
#
#    combina_2 train.shape.1     media       std    minimo    maximo  \
# 0         37     (1350, 6)  0.481278  0.029213  0.432987  0.516043
# 1         29     (1350, 6)  0.476666  0.024799  0.444120  0.516350
# 2         48     (1350, 6)  0.476297  0.012259  0.456265  0.492814
# 3         21     (1350, 6)  0.475935  0.015158  0.459159  0.502234
# 4         34     (1350, 6)  0.475496  0.021153  0.447429  0.497836
# 5         47     (1350, 6)  0.475265  0.028622  0.428454  0.515660
# 6         64     (1350, 6)  0.474978  0.033086  0.426300  0.525850
# 7         73     (1350, 6)  0.474900  0.032962  0.436733  0.531947
#
#                                                                                               scores_kfold  \
# 0     [0.4666290111620419, 0.48778924763159526, 0.5160430398197133, 0.502942668091141, 0.4329872079481898]
# 1    [0.4728020157634094, 0.4605266814391304, 0.5163499424062804, 0.48953223816594016, 0.4441201676974035]
# 2  [0.47277592855323947, 0.4928138763136177, 0.47533211456818814, 0.4842967175730204, 0.45626464318639204]
# 3    [0.46300608544460997, 0.4788023105211132, 0.5022340882483275, 0.4764749617852114, 0.4591588558500323]
# 4     [0.447428941019795, 0.49783610903526565, 0.4819171202396455, 0.4964672307113028, 0.4538289078862101]
# 5    [0.46551525143413963, 0.4784835132363422, 0.515659856088169, 0.48820983224185877, 0.4284544736322339]
# 6   [0.4615849146676215, 0.49227904394642363, 0.5258504282761332, 0.46887561337796313, 0.4263003383384278]
# 7    [0.4679392152148094, 0.45159485919890785, 0.531947335410183, 0.4862867553187819, 0.43673299910804914]
#
#        diff
# 0  0.016399
# 1  0.011787
# 2  0.011417
# 3  0.011056
# 4  0.010616
# 5  0.010385
# 6  0.010099
# 7  0.010021

# %%
_ = df_.loc[df_['dataset'] == 'haha21'].sort_values(by=['f1'], ascending=False)
empty_f1 = _.loc[_['combina_1'] == 50].f1.iat[0]
dse = _.loc[(_['f1'] > empty_f1) | (_['combina_1'] == 50)]    
dse['diff'] = dse.apply(lambda row: row.f1 - empty_f1, axis=1) 
print(empty_f1)
dse
dse[['combina_1']].to_string

# %%
_ = df_.loc[df_['dataset'] == 'misogyny_centrogeo'].sort_values(by=['media'], ascending=False)
empty_val = _.loc[_['combina_1'] == 50].media.iat[0]
dse = _.loc[(_['media'] > empty_val) | (_['combina_1'] == 50)]    
dse['diff'] = dse.apply(lambda row: row.media - empty_val, axis=1) 
print(empty_val)
#dse[['combina_1']].to_string
dse

# %%
_ = df_.loc[df_['dataset'] == ds_n].sort_values(by=['media'], ascending=False)
empty_value = _.loc[_['combina_1'] == 50].media.iat[0]
dse = _.loc[(_['media'] > empty_value) | (_['combina_1'] == 50)]    
dse['diff'] = dse.apply(lambda row: row.media - empty_value, axis=1) 
dse = dse.loc[dse['diff'] > 0.01]  
ds_final = pd.concat([ds_final, dse], ignore_index=True)

# %%
/home/juan.calderon/anaconda3/envs/watermelon/lib/python3.10/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
  warnings.warn(
