# %%
from EvoMSA.base import EvoMSA
from microtc.utils import load_model, save_model
from itertools import combinations
import random
import numpy as np
from glob import glob
from joblib import Parallel, delayed
import joblib as joblib
import pandas as pd
from sklearn import metrics
import winsound

import warnings
warnings.filterwarnings("ignore")

pd.set_option('display.max_colwidth', None)

winsound.Beep(3000, 900)

# %%
winsound.Beep(4500, 300)

# %%
stacked_method = "sklearn.svm.LinearSVC"

# 8 Models Pre-Trained EvoMSA
pre_models_dict = {
    "davincis22": [load_model('pre_models/davincis22_Es.evomsa'), stacked_method],
    "detoxis21_aggressiveness" : [load_model('pre_models/detoxis21_aggressiveness_Es.evomsa'), stacked_method],
    "exist21" : [load_model('pre_models/exist21_Es.evomsa'), stacked_method],
    "haha21" : [load_model('pre_models/haha21_Es.evomsa'), stacked_method],
    "meoffendes21" : [load_model('pre_models/meoffendes21_Es.evomsa'), stacked_method],
    "mexa3t18_aggress" : [load_model('pre_models/mexa3t18_aggress_Es.evomsa'), stacked_method],
    "misogyny_centrogeo" : [load_model('pre_models/misogyny_centrogeo_Es.evomsa'), stacked_method],
    "metwo22" : [load_model('pre_models/metwo22_Es.evomsa'), stacked_method]
}  

print(len(pre_models_dict.keys()), pre_models_dict.keys())
# Out:
# 8 dict_keys(['davincis22', 'detoxis21_aggressiveness', 'exist21', 'haha21', 'meoffendes21', 'mexa3t18_aggress', 'misogyny_centrogeo', 'metwo22'])

# %%
combinaciones = []
items = pre_models_dict.keys()
for i in range(1, len(items)):
    combs = combinations(items, i+1)
    n_c = sum(1 for e in combs)
    print(i, n_c, combs)
    combs = combinations(items, i+1)
    for c in combs:
        #print(c)
        combinaciones.append(c)
len(combinaciones)     ### 247 combinaciones de 2 a 8 elementos
# Out:
# 1 28 <itertools.combinations object at 0x000001FC2A9BE4A0>
# 2 56 <itertools.combinations object at 0x000001FC2A9BE4A0>
# 3 70 <itertools.combinations object at 0x000001FC2A9BE4A0>
# 4 56 <itertools.combinations object at 0x000001FC2A9BE4A0>
# 5 28 <itertools.combinations object at 0x000001FC2A9BE4A0>
# 6 8 <itertools.combinations object at 0x000001FC2A9BE4A0>
# 7 1 <itertools.combinations object at 0x000001FC2A9BE4A0>
# 247

# %%
# tomar random 60 
samples = random.sample(combinaciones, 80)

# agregar los single models para garantizar que existan    
for p in pre_models_dict:
    samples.append((p, np.nan))

# agegar conjunto vacio
samples.append(()) 

len(samples), samples
# Out:
# (89,
#  [('exist21', 'meoffendes21', 'misogyny_centrogeo'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'exist21',
#    'haha21',
#    'mexa3t18_aggress'),
#   ('davincis22', 'mexa3t18_aggress'),
#   ('haha21', 'meoffendes21'),
#   ('detoxis21_aggressiveness', 'haha21', 'misogyny_centrogeo', 'metwo22'),
#   ('davincis22', 'meoffendes21', 'mexa3t18_aggress'),
#   ('mexa3t18_aggress', 'misogyny_centrogeo', 'metwo22'),
#   ('exist21', 'meoffendes21', 'metwo22'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'meoffendes21',
#    'misogyny_centrogeo'),
#   ('davincis22', 'exist21', 'haha21', 'mexa3t18_aggress'),
#   ('davincis22', 'detoxis21_aggressiveness', 'haha21', 'misogyny_centrogeo'),
#   ('detoxis21_aggressiveness',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo'),
#   ('detoxis21_aggressiveness', 'haha21', 'mexa3t18_aggress', 'metwo22'),
#   ('davincis22', 'exist21', 'meoffendes21', 'mexa3t18_aggress', 'metwo22'),
#   ('detoxis21_aggressiveness', 'mexa3t18_aggress', 'metwo22'),
#   ('detoxis21_aggressiveness', 'haha21', 'meoffendes21', 'misogyny_centrogeo'),
#   ('haha21', 'meoffendes21', 'mexa3t18_aggress'),
#   ('haha21', 'meoffendes21', 'mexa3t18_aggress', 'metwo22'),
#   ('haha21', 'mexa3t18_aggress', 'metwo22'),
#   ('detoxis21_aggressiveness',
#    'haha21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('davincis22', 'exist21', 'misogyny_centrogeo'),
#   ('davincis22', 'exist21', 'haha21'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'exist21',
#    'haha21',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'exist21',
#    'meoffendes21',
#    'mexa3t18_aggress'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'exist21',
#    'haha21',
#    'meoffendes21'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'haha21',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'metwo22'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'exist21',
#    'haha21',
#    'meoffendes21',
#    'mexa3t18_aggress'),
#   ('detoxis21_aggressiveness', 'mexa3t18_aggress', 'misogyny_centrogeo'),
#   ('detoxis21_aggressiveness',
#    'haha21',
#    'meoffendes21',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('davincis22', 'exist21', 'meoffendes21', 'misogyny_centrogeo', 'metwo22'),
#   ('davincis22', 'meoffendes21'),
#   ('detoxis21_aggressiveness', 'haha21', 'mexa3t18_aggress'),
#   ('detoxis21_aggressiveness',
#    'exist21',
#    'haha21',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('exist21', 'mexa3t18_aggress', 'metwo22'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'exist21',
#    'haha21',
#    'misogyny_centrogeo'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'exist21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo'),
#   ('davincis22', 'detoxis21_aggressiveness', 'mexa3t18_aggress', 'metwo22'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'exist21',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('detoxis21_aggressiveness',
#    'haha21',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo'),
#   ('davincis22',
#    'exist21',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo'),
#   ('detoxis21_aggressiveness', 'exist21', 'haha21', 'meoffendes21', 'metwo22'),
#   ('detoxis21_aggressiveness',
#    'exist21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('exist21', 'meoffendes21', 'mexa3t18_aggress', 'misogyny_centrogeo'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'haha21',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo'),
#   ('davincis22', 'haha21', 'meoffendes21', 'metwo22'),
#   ('davincis22',
#    'exist21',
#    'haha21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo'),
#   ('davincis22', 'exist21', 'haha21', 'meoffendes21'),
#   ('davincis22',
#    'exist21',
#    'haha21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('davincis22', 'misogyny_centrogeo', 'metwo22'),
#   ('detoxis21_aggressiveness', 'haha21', 'misogyny_centrogeo'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'haha21',
#    'meoffendes21',
#    'mexa3t18_aggress'),
#   ('davincis22', 'haha21', 'mexa3t18_aggress'),
#   ('davincis22', 'exist21', 'mexa3t18_aggress', 'misogyny_centrogeo'),
#   ('exist21', 'meoffendes21', 'misogyny_centrogeo', 'metwo22'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'exist21',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo'),
#   ('detoxis21_aggressiveness',
#    'exist21',
#    'meoffendes21',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('detoxis21_aggressiveness',
#    'haha21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo'),
#   ('detoxis21_aggressiveness',
#    'exist21',
#    'haha21',
#    'meoffendes21',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'exist21',
#    'haha21',
#    'mexa3t18_aggress',
#    'metwo22'),
#   ('exist21', 'haha21', 'mexa3t18_aggress', 'metwo22'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo'),
#   ('davincis22', 'detoxis21_aggressiveness', 'meoffendes21'),
#   ('detoxis21_aggressiveness', 'misogyny_centrogeo', 'metwo22'),
#   ('exist21', 'haha21', 'meoffendes21', 'mexa3t18_aggress'),
#   ('davincis22', 'haha21', 'mexa3t18_aggress', 'metwo22'),
#   ('exist21', 'meoffendes21', 'mexa3t18_aggress'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'exist21',
#    'haha21',
#    'meoffendes21',
#    'misogyny_centrogeo'),
#   ('davincis22', 'mexa3t18_aggress', 'metwo22'),
#   ('detoxis21_aggressiveness',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo'),
#   ('davincis22', 'exist21', 'mexa3t18_aggress', 'metwo22'),
#   ('davincis22', 'exist21', 'meoffendes21', 'misogyny_centrogeo'),
#   ('haha21', 'misogyny_centrogeo', 'metwo22'),
#   ('davincis22', 'exist21', 'meoffendes21', 'metwo22'),
#   ('davincis22', 'detoxis21_aggressiveness', 'exist21', 'meoffendes21'),
#   ('exist21', 'haha21', 'misogyny_centrogeo', 'metwo22'),
#   ('detoxis21_aggressiveness', 'exist21', 'meoffendes21', 'metwo22'),
#   ('davincis22', 'exist21', 'haha21', 'meoffendes21', 'mexa3t18_aggress'),
#   ('davincis22', 'haha21', 'meoffendes21'),
#   ('haha21', 'metwo22'),
#   ('davincis22', nan),
#   ('detoxis21_aggressiveness', nan),
#   ('exist21', nan),
#   ('haha21', nan),
#   ('meoffendes21', nan),
#   ('mexa3t18_aggress', nan),
#   ('misogyny_centrogeo', nan),
#   ('metwo22', nan),
#   ()])

# %%
df_samples =  pd.DataFrame(samples)
df_samples.to_csv('premodels_combinations_89.csv')

# %%
pd.set_option('display.max_colwidth', None)
pd.options.display.max_rows = 1200
df_samples
# Out:
#                            0                         1                   2  \
# 0                    exist21              meoffendes21  misogyny_centrogeo
# 1                 davincis22  detoxis21_aggressiveness             exist21
# 2                 davincis22          mexa3t18_aggress                None
# 3                     haha21              meoffendes21                None
# 4   detoxis21_aggressiveness                    haha21  misogyny_centrogeo
# 5                 davincis22              meoffendes21    mexa3t18_aggress
# 6           mexa3t18_aggress        misogyny_centrogeo             metwo22
# 7                    exist21              meoffendes21             metwo22
# 8                 davincis22  detoxis21_aggressiveness        meoffendes21
# 9                 davincis22                   exist21              haha21
# 10                davincis22  detoxis21_aggressiveness              haha21
# 11  detoxis21_aggressiveness              meoffendes21    mexa3t18_aggress
# 12  detoxis21_aggressiveness                    haha21    mexa3t18_aggress
# 13                davincis22                   exist21        meoffendes21
# 14  detoxis21_aggressiveness          mexa3t18_aggress             metwo22
# 15  detoxis21_aggressiveness                    haha21        meoffendes21
# 16                    haha21              meoffendes21    mexa3t18_aggress
# 17                    haha21              meoffendes21    mexa3t18_aggress
# 18                    haha21          mexa3t18_aggress             metwo22
# 19  detoxis21_aggressiveness                    haha21    mexa3t18_aggress
# 20                davincis22                   exist21  misogyny_centrogeo
# 21                davincis22                   exist21              haha21
# 22                davincis22  detoxis21_aggressiveness             exist21
# 23                davincis22  detoxis21_aggressiveness             exist21
# 24                davincis22  detoxis21_aggressiveness             exist21
# 25                davincis22  detoxis21_aggressiveness              haha21
# 26                davincis22  detoxis21_aggressiveness             exist21
# 27  detoxis21_aggressiveness          mexa3t18_aggress  misogyny_centrogeo
# 28  detoxis21_aggressiveness                    haha21        meoffendes21
# 29                davincis22                   exist21        meoffendes21
# 30                davincis22              meoffendes21                None
# 31  detoxis21_aggressiveness                    haha21    mexa3t18_aggress
# 32  detoxis21_aggressiveness                   exist21              haha21
# 33                   exist21          mexa3t18_aggress             metwo22
# 34                davincis22  detoxis21_aggressiveness             exist21
# 35                davincis22  detoxis21_aggressiveness             exist21
# 36                davincis22  detoxis21_aggressiveness    mexa3t18_aggress
# 37                davincis22  detoxis21_aggressiveness             exist21
# 38  detoxis21_aggressiveness                    haha21        meoffendes21
# 39                davincis22                   exist21        meoffendes21
# 40  detoxis21_aggressiveness                   exist21              haha21
# 41  detoxis21_aggressiveness                   exist21    mexa3t18_aggress
# 42                   exist21              meoffendes21    mexa3t18_aggress
# 43                davincis22  detoxis21_aggressiveness              haha21
# 44                davincis22                    haha21        meoffendes21
# 45                davincis22                   exist21              haha21
# 46                davincis22                   exist21              haha21
# 47                davincis22                   exist21              haha21
# 48                davincis22        misogyny_centrogeo             metwo22
# 49  detoxis21_aggressiveness                    haha21  misogyny_centrogeo
# 50                davincis22  detoxis21_aggressiveness              haha21
# 51                davincis22                    haha21    mexa3t18_aggress
# 52                davincis22                   exist21    mexa3t18_aggress
# 53                   exist21              meoffendes21  misogyny_centrogeo
# 54                davincis22  detoxis21_aggressiveness             exist21
# 55  detoxis21_aggressiveness                   exist21        meoffendes21
# 56  detoxis21_aggressiveness                    haha21    mexa3t18_aggress
# 57  detoxis21_aggressiveness                   exist21              haha21
# 58                davincis22  detoxis21_aggressiveness             exist21
# 59                   exist21                    haha21    mexa3t18_aggress
# 60                davincis22  detoxis21_aggressiveness        meoffendes21
# 61                davincis22  detoxis21_aggressiveness        meoffendes21
# 62  detoxis21_aggressiveness        misogyny_centrogeo             metwo22
# 63                   exist21                    haha21        meoffendes21
# 64                davincis22                    haha21    mexa3t18_aggress
# 65                   exist21              meoffendes21    mexa3t18_aggress
# 66                davincis22  detoxis21_aggressiveness             exist21
# 67                davincis22          mexa3t18_aggress             metwo22
# 68  detoxis21_aggressiveness              meoffendes21    mexa3t18_aggress
# 69                davincis22  detoxis21_aggressiveness    mexa3t18_aggress
# 70                davincis22                   exist21    mexa3t18_aggress
# 71                davincis22                   exist21        meoffendes21
# 72                    haha21        misogyny_centrogeo             metwo22
# 73                davincis22                   exist21        meoffendes21
# 74                davincis22  detoxis21_aggressiveness             exist21
# 75                   exist21                    haha21  misogyny_centrogeo
# 76  detoxis21_aggressiveness                   exist21        meoffendes21
# 77                davincis22                   exist21              haha21
# 78                davincis22                    haha21        meoffendes21
# 79                    haha21                   metwo22                None
# 80                davincis22                       NaN                None
# 81  detoxis21_aggressiveness                       NaN                None
# 82                   exist21                       NaN                None
# 83                    haha21                       NaN                None
# 84              meoffendes21                       NaN                None
# 85          mexa3t18_aggress                       NaN                None
# 86        misogyny_centrogeo                       NaN                None
# 87                   metwo22                       NaN                None
# 88                      None                      None                None
#
#                      3                   4                   5  \
# 0                 None                None                None
# 1               haha21    mexa3t18_aggress                None
# 2                 None                None                None
# 3                 None                None                None
# 4              metwo22                None                None
# 5                 None                None                None
# 6                 None                None                None
# 7                 None                None                None
# 8   misogyny_centrogeo                None                None
# 9     mexa3t18_aggress                None                None
# 10  misogyny_centrogeo                None                None
# 11  misogyny_centrogeo                None                None
# 12             metwo22                None                None
# 13    mexa3t18_aggress             metwo22                None
# 14                None                None                None
# 15  misogyny_centrogeo                None                None
# 16                None                None                None
# 17             metwo22                None                None
# 18                None                None                None
# 19  misogyny_centrogeo             metwo22                None
# 20                None                None                None
# 21                None                None                None
# 22              haha21        meoffendes21    mexa3t18_aggress
# 23        meoffendes21    mexa3t18_aggress                None
# 24              haha21        meoffendes21                None
# 25        meoffendes21    mexa3t18_aggress             metwo22
# 26              haha21        meoffendes21    mexa3t18_aggress
# 27                None                None                None
# 28  misogyny_centrogeo             metwo22                None
# 29  misogyny_centrogeo             metwo22                None
# 30                None                None                None
# 31                None                None                None
# 32  misogyny_centrogeo             metwo22                None
# 33                None                None                None
# 34              haha21  misogyny_centrogeo                None
# 35    mexa3t18_aggress  misogyny_centrogeo                None
# 36             metwo22                None                None
# 37  misogyny_centrogeo             metwo22                None
# 38    mexa3t18_aggress  misogyny_centrogeo                None
# 39    mexa3t18_aggress  misogyny_centrogeo                None
# 40        meoffendes21             metwo22                None
# 41  misogyny_centrogeo             metwo22                None
# 42  misogyny_centrogeo                None                None
# 43        meoffendes21    mexa3t18_aggress  misogyny_centrogeo
# 44             metwo22                None                None
# 45    mexa3t18_aggress  misogyny_centrogeo                None
# 46        meoffendes21                None                None
# 47    mexa3t18_aggress  misogyny_centrogeo             metwo22
# 48                None                None                None
# 49                None                None                None
# 50        meoffendes21    mexa3t18_aggress                None
# 51                None                None                None
# 52  misogyny_centrogeo                None                None
# 53             metwo22                None                None
# 54        meoffendes21    mexa3t18_aggress  misogyny_centrogeo
# 55  misogyny_centrogeo             metwo22                None
# 56  misogyny_centrogeo                None                None
# 57        meoffendes21  misogyny_centrogeo             metwo22
# 58              haha21    mexa3t18_aggress             metwo22
# 59             metwo22                None                None
# 60    mexa3t18_aggress  misogyny_centrogeo                None
# 61                None                None                None
# 62                None                None                None
# 63    mexa3t18_aggress                None                None
# 64             metwo22                None                None
# 65                None                None                None
# 66              haha21        meoffendes21  misogyny_centrogeo
# 67                None                None                None
# 68  misogyny_centrogeo             metwo22                None
# 69  misogyny_centrogeo                None                None
# 70             metwo22                None                None
# 71  misogyny_centrogeo                None                None
# 72                None                None                None
# 73             metwo22                None                None
# 74        meoffendes21                None                None
# 75             metwo22                None                None
# 76             metwo22                None                None
# 77        meoffendes21    mexa3t18_aggress                None
# 78                None                None                None
# 79                None                None                None
# 80                None                None                None
# 81                None                None                None
# 82                None                None                None
# 83                None                None                None
# 84                None                None                None
# 85                None                None                None
# 86                None                None                None
# 87                None                None                None
# 88                None                None                None
#
#                      6        7
# 0                 None     None
# 1                 None     None
# 2                 None     None
# 3                 None     None
# 4                 None     None
# 5                 None     None
# 6                 None     None
# 7                 None     None
# 8                 None     None
# 9                 None     None
# 10                None     None
# 11                None     None
# 12                None     None
# 13                None     None
# 14                None     None
# 15                None     None
# 16                None     None
# 17                None     None
# 18                None     None
# 19                None     None
# 20                None     None
# 21                None     None
# 22  misogyny_centrogeo  metwo22
# 23                None     None
# 24                None     None
# 25                None     None
# 26                None     None
# 27                None     None
# 28                None     None
# 29                None     None
# 30                None     None
# 31                None     None
# 32                None     None
# 33                None     None
# 34                None     None
# 35                None     None
# 36                None     None
# 37                None     None
# 38                None     None
# 39                None     None
# 40                None     None
# 41                None     None
# 42                None     None
# 43                None     None
# 44                None     None
# 45                None     None
# 46                None     None
# 47                None     None
# 48                None     None
# 49                None     None
# 50                None     None
# 51                None     None
# 52                None     None
# 53                None     None
# 54                None     None
# 55                None     None
# 56                None     None
# 57                None     None
# 58                None     None
# 59                None     None
# 60                None     None
# 61                None     None
# 62                None     None
# 63                None     None
# 64                None     None
# 65                None     None
# 66                None     None
# 67                None     None
# 68                None     None
# 69                None     None
# 70                None     None
# 71                None     None
# 72                None     None
# 73                None     None
# 74                None     None
# 75                None     None
# 76                None     None
# 77                None     None
# 78                None     None
# 79                None     None
# 80                None     None
# 81                None     None
# 82                None     None
# 83                None     None
# 84                None     None
# 85                None     None
# 86                None     None
# 87                None     None
# 88                None     None

# %%
# 17 Datasets
for i, fn in enumerate(glob("../dataset_es/*_Es_train.json")):
    train_df = pd.read_json(fn, lines=True)
    test_df = pd.read_json(fn.replace("_train", "_test"), lines=True)
    ds_n = fn.replace("..\\dataset_es\\",'').replace("../dataset_es\\",'').replace('_Es_train.json','')
    print(i, ds_n, train_df.shape, test_df.shape)
# Out:
# 0 davincis22 (2521, 2) (841, 2)
# 1 detoxis21_aggressiveness (2770, 2) (693, 2)
# 2 detoxis21_insult (2770, 2) (693, 2)
# 3 detoxis21_intolerance (2770, 2) (693, 2)
# 4 detoxis21_mockery (2770, 2) (693, 2)
# 5 detoxis21_sarcasm (2770, 2) (693, 2)
# 6 detoxis21_stereotype (2770, 2) (693, 2)
# 7 detoxis21_toxicity (2770, 2) (693, 2)
# 8 exist21 (2655, 2) (886, 2)
# 9 haha21 (18000, 2) (6000, 2)
# 10 meoffendes21 (3795, 2) (1265, 2)
# 11 metwo22 (2880, 2) (720, 2)
# 12 mexa3t18_aggress (5389, 5) (2311, 5)
# 13 misoginia (2645, 5) (662, 5)
# 14 misogyny_centrogeo (5752, 2) (1439, 2)
# 15 semeval2018_anger (1359, 6) (627, 6)
# 16 semeval2018_sadness (1350, 6) (641, 6)

# %%
# 17 Datasets
d = []
for i, fn in enumerate(glob("../dataset_es/*_Es_train.json")):
    train_df = pd.read_json(fn, lines=True)
    test_df = pd.read_json(fn.replace("_train", "_test"), lines=True)
    ds_n = fn.replace("..\\dataset_es\\",'').replace("../dataset_es\\",'').replace('_Es_train.json','')
    d.append({'dataset': ds_n, 'train_shape': train_df.shape, 'test_shape':test_df.shape})
df2 = pd.DataFrame(d)
df2.to_csv('dataset_shapes_17.csv')
df2
# Out:
#                      dataset train_shape test_shape
# 0                 davincis22   (2521, 2)   (841, 2)
# 1   detoxis21_aggressiveness   (2770, 2)   (693, 2)
# 2           detoxis21_insult   (2770, 2)   (693, 2)
# 3      detoxis21_intolerance   (2770, 2)   (693, 2)
# 4          detoxis21_mockery   (2770, 2)   (693, 2)
# 5          detoxis21_sarcasm   (2770, 2)   (693, 2)
# 6       detoxis21_stereotype   (2770, 2)   (693, 2)
# 7         detoxis21_toxicity   (2770, 2)   (693, 2)
# 8                    exist21   (2655, 2)   (886, 2)
# 9                     haha21  (18000, 2)  (6000, 2)
# 10              meoffendes21   (3795, 2)  (1265, 2)
# 11                   metwo22   (2880, 2)   (720, 2)
# 12          mexa3t18_aggress   (5389, 5)  (2311, 5)
# 13                 misoginia   (2645, 5)   (662, 5)
# 14        misogyny_centrogeo   (5752, 2)  (1439, 2)
# 15         semeval2018_anger   (1359, 6)   (627, 6)
# 16       semeval2018_sadness   (1350, 6)   (641, 6)

# %% [markdown]
# ---
