# %%
from EvoMSA.base import EvoMSA
from microtc.utils import load_model, save_model
from itertools import combinations
import random
import numpy as np
from glob import glob
from joblib import Parallel, delayed
import joblib as joblib
import pandas as pd
from sklearn import metrics
import winsound

import warnings
warnings.filterwarnings("ignore")

pd.set_option('display.max_colwidth', None)

winsound.Beep(3000, 900)

# %%
winsound.Beep(4500, 300)

# %%
stacked_method = "sklearn.svm.LinearSVC"

# 8 Models Pre-Trained EvoMSA
pre_models_dict = {
    "davincis22": [load_model('pre_models/davincis22_Es.evomsa'), stacked_method],
    "detoxis21_aggressiveness" : [load_model('pre_models/detoxis21_aggressiveness_Es.evomsa'), stacked_method],
    "exist21" : [load_model('pre_models/exist21_Es.evomsa'), stacked_method],
    "haha21" : [load_model('pre_models/haha21_Es.evomsa'), stacked_method],
    "meoffendes21" : [load_model('pre_models/meoffendes21_Es.evomsa'), stacked_method],
    "mexa3t18_aggress" : [load_model('pre_models/mexa3t18_aggress_Es.evomsa'), stacked_method],
    "misogyny_centrogeo" : [load_model('pre_models/misogyny_centrogeo_Es.evomsa'), stacked_method],
    "metwo22" : [load_model('pre_models/metwo22_Es.evomsa'), stacked_method]
}  

print(len(pre_models_dict.keys()), pre_models_dict.keys())
# Out:
# 8 dict_keys(['davincis22', 'detoxis21_aggressiveness', 'exist21', 'haha21', 'meoffendes21', 'mexa3t18_aggress', 'misogyny_centrogeo', 'metwo22'])

# %%
combinaciones = []
items = pre_models_dict.keys()
for i in range(1, len(items)):
    combs = combinations(items, i+1)
    n_c = sum(1 for e in combs)
    print(i, n_c, combs)
    combs = combinations(items, i+1)
    for c in combs:
        #print(c)
        combinaciones.append(c)
len(combinaciones)     ### 247 combinaciones de 2 a 8 elementos
# Out:
# 1 28 <itertools.combinations object at 0x000002903EBCB770>
# 2 56 <itertools.combinations object at 0x000002903EBCB770>
# 3 70 <itertools.combinations object at 0x000002903EBCB770>
# 4 56 <itertools.combinations object at 0x000002903EBCB770>
# 5 28 <itertools.combinations object at 0x000002903EBCB770>
# 6 8 <itertools.combinations object at 0x000002903EBCB770>
# 7 1 <itertools.combinations object at 0x000002903EBCB770>
# 247

# %%
# tomar random 60 
samples = random.sample(combinaciones, 80)

# agregar los single models para garantizar que existan    
for p in pre_models_dict:
    samples.append((p, np.nan))

# agegar conjunto vacio
samples.append(()) 

len(samples), samples
# Out:
# (89,
#  [('meoffendes21', 'mexa3t18_aggress'),
#   ('davincis22',
#    'haha21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('exist21', 'haha21', 'meoffendes21', 'mexa3t18_aggress', 'metwo22'),
#   ('haha21', 'metwo22'),
#   ('davincis22', 'detoxis21_aggressiveness', 'mexa3t18_aggress'),
#   ('exist21', 'haha21', 'mexa3t18_aggress', 'misogyny_centrogeo'),
#   ('mexa3t18_aggress', 'misogyny_centrogeo', 'metwo22'),
#   ('davincis22', 'exist21', 'haha21', 'mexa3t18_aggress'),
#   ('davincis22', 'haha21', 'meoffendes21', 'mexa3t18_aggress', 'metwo22'),
#   ('exist21', 'meoffendes21', 'misogyny_centrogeo', 'metwo22'),
#   ('detoxis21_aggressiveness',
#    'exist21',
#    'meoffendes21',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'meoffendes21',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'metwo22'),
#   ('detoxis21_aggressiveness',
#    'haha21',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo'),
#   ('exist21', 'haha21', 'meoffendes21', 'mexa3t18_aggress'),
#   ('misogyny_centrogeo', 'metwo22'),
#   ('detoxis21_aggressiveness',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('detoxis21_aggressiveness', 'haha21', 'meoffendes21'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'exist21',
#    'meoffendes21',
#    'mexa3t18_aggress'),
#   ('davincis22', 'misogyny_centrogeo', 'metwo22'),
#   ('detoxis21_aggressiveness', 'exist21', 'haha21'),
#   ('exist21', 'meoffendes21', 'misogyny_centrogeo'),
#   ('davincis22',
#    'exist21',
#    'haha21',
#    'meoffendes21',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('haha21', 'meoffendes21', 'mexa3t18_aggress'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'exist21',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'exist21',
#    'meoffendes21',
#    'misogyny_centrogeo'),
#   ('haha21', 'meoffendes21', 'mexa3t18_aggress', 'metwo22'),
#   ('exist21', 'mexa3t18_aggress', 'misogyny_centrogeo', 'metwo22'),
#   ('davincis22', 'detoxis21_aggressiveness', 'haha21', 'metwo22'),
#   ('detoxis21_aggressiveness', 'exist21', 'misogyny_centrogeo'),
#   ('davincis22',
#    'exist21',
#    'haha21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('detoxis21_aggressiveness',
#    'haha21',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'metwo22'),
#   ('davincis22', 'exist21', 'meoffendes21', 'misogyny_centrogeo', 'metwo22'),
#   ('davincis22',
#    'exist21',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo'),
#   ('davincis22', 'detoxis21_aggressiveness', 'haha21', 'misogyny_centrogeo'),
#   ('exist21', 'haha21', 'mexa3t18_aggress', 'misogyny_centrogeo', 'metwo22'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'exist21',
#    'haha21',
#    'meoffendes21',
#    'metwo22'),
#   ('davincis22', 'meoffendes21', 'misogyny_centrogeo', 'metwo22'),
#   ('davincis22', 'detoxis21_aggressiveness', 'exist21', 'misogyny_centrogeo'),
#   ('detoxis21_aggressiveness', 'exist21'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'exist21',
#    'meoffendes21',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('davincis22', 'haha21', 'metwo22'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'haha21',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo'),
#   ('davincis22', 'meoffendes21', 'misogyny_centrogeo'),
#   ('davincis22',
#    'exist21',
#    'haha21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo'),
#   ('detoxis21_aggressiveness', 'haha21'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'haha21',
#    'meoffendes21',
#    'misogyny_centrogeo'),
#   ('detoxis21_aggressiveness', 'meoffendes21', 'mexa3t18_aggress', 'metwo22'),
#   ('detoxis21_aggressiveness', 'haha21', 'meoffendes21', 'metwo22'),
#   ('detoxis21_aggressiveness',
#    'exist21',
#    'haha21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('davincis22',
#    'haha21',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'exist21',
#    'haha21',
#    'mexa3t18_aggress',
#    'metwo22'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'exist21',
#    'haha21',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo'),
#   ('haha21', 'misogyny_centrogeo'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'haha21',
#    'mexa3t18_aggress',
#    'metwo22'),
#   ('exist21', 'haha21', 'meoffendes21'),
#   ('davincis22', 'exist21'),
#   ('davincis22', 'detoxis21_aggressiveness', 'meoffendes21'),
#   ('davincis22', 'detoxis21_aggressiveness'),
#   ('davincis22', 'exist21', 'haha21'),
#   ('davincis22', 'exist21', 'haha21', 'metwo22'),
#   ('davincis22', 'detoxis21_aggressiveness', 'exist21', 'metwo22'),
#   ('davincis22', 'detoxis21_aggressiveness', 'meoffendes21', 'metwo22'),
#   ('davincis22', 'haha21', 'meoffendes21', 'mexa3t18_aggress'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'meoffendes21',
#    'misogyny_centrogeo'),
#   ('detoxis21_aggressiveness', 'mexa3t18_aggress', 'metwo22'),
#   ('davincis22', 'meoffendes21'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'haha21',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('davincis22', 'haha21', 'mexa3t18_aggress'),
#   ('davincis22',
#    'haha21',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('haha21',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'haha21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo'),
#   ('exist21', 'meoffendes21', 'mexa3t18_aggress', 'misogyny_centrogeo'),
#   ('davincis22', 'detoxis21_aggressiveness', 'haha21', 'mexa3t18_aggress'),
#   ('davincis22', 'haha21', 'meoffendes21', 'metwo22'),
#   ('detoxis21_aggressiveness',
#    'exist21',
#    'haha21',
#    'mexa3t18_aggress',
#    'metwo22'),
#   ('davincis22',
#    'detoxis21_aggressiveness',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('exist21',
#    'haha21',
#    'meoffendes21',
#    'mexa3t18_aggress',
#    'misogyny_centrogeo',
#    'metwo22'),
#   ('davincis22', 'exist21', 'haha21', 'misogyny_centrogeo', 'metwo22'),
#   ('exist21', 'meoffendes21', 'mexa3t18_aggress', 'metwo22'),
#   ('davincis22', nan),
#   ('detoxis21_aggressiveness', nan),
#   ('exist21', nan),
#   ('haha21', nan),
#   ('meoffendes21', nan),
#   ('mexa3t18_aggress', nan),
#   ('misogyny_centrogeo', nan),
#   ('metwo22', nan),
#   ()])

# %%
df_samples =  pd.DataFrame(samples)
df_samples.to_csv('premodels_combinations_89.csv')

# %%
pd.set_option('display.max_colwidth', None)
pd.options.display.max_rows = 1200
df_samples
# Out:
#                            0                         1                   2  \
# 0               meoffendes21          mexa3t18_aggress                None
# 1                 davincis22                    haha21    mexa3t18_aggress
# 2                    exist21                    haha21        meoffendes21
# 3                     haha21                   metwo22                None
# 4                 davincis22  detoxis21_aggressiveness    mexa3t18_aggress
# 5                    exist21                    haha21    mexa3t18_aggress
# 6           mexa3t18_aggress        misogyny_centrogeo             metwo22
# 7                 davincis22                   exist21              haha21
# 8                 davincis22                    haha21        meoffendes21
# 9                    exist21              meoffendes21  misogyny_centrogeo
# 10  detoxis21_aggressiveness                   exist21        meoffendes21
# 11                davincis22  detoxis21_aggressiveness        meoffendes21
# 12                davincis22  detoxis21_aggressiveness        meoffendes21
# 13  detoxis21_aggressiveness                    haha21        meoffendes21
# 14                   exist21                    haha21        meoffendes21
# 15        misogyny_centrogeo                   metwo22                None
# 16  detoxis21_aggressiveness              meoffendes21    mexa3t18_aggress
# 17  detoxis21_aggressiveness                    haha21        meoffendes21
# 18                davincis22  detoxis21_aggressiveness             exist21
# 19                davincis22        misogyny_centrogeo             metwo22
# 20  detoxis21_aggressiveness                   exist21              haha21
# 21                   exist21              meoffendes21  misogyny_centrogeo
# 22                davincis22                   exist21              haha21
# 23                    haha21              meoffendes21    mexa3t18_aggress
# 24                davincis22  detoxis21_aggressiveness             exist21
# 25                davincis22  detoxis21_aggressiveness             exist21
# 26                    haha21              meoffendes21    mexa3t18_aggress
# 27                   exist21          mexa3t18_aggress  misogyny_centrogeo
# 28                davincis22  detoxis21_aggressiveness              haha21
# 29  detoxis21_aggressiveness                   exist21  misogyny_centrogeo
# 30                davincis22                   exist21              haha21
# 31  detoxis21_aggressiveness                    haha21        meoffendes21
# 32                davincis22                   exist21        meoffendes21
# 33                davincis22                   exist21        meoffendes21
# 34                davincis22  detoxis21_aggressiveness              haha21
# 35                   exist21                    haha21    mexa3t18_aggress
# 36                davincis22  detoxis21_aggressiveness             exist21
# 37                davincis22              meoffendes21  misogyny_centrogeo
# 38                davincis22  detoxis21_aggressiveness             exist21
# 39  detoxis21_aggressiveness                   exist21                None
# 40                davincis22  detoxis21_aggressiveness             exist21
# 41                davincis22                    haha21             metwo22
# 42                davincis22  detoxis21_aggressiveness              haha21
# 43                davincis22              meoffendes21  misogyny_centrogeo
# 44                davincis22                   exist21              haha21
# 45  detoxis21_aggressiveness                    haha21                None
# 46                davincis22  detoxis21_aggressiveness              haha21
# 47  detoxis21_aggressiveness              meoffendes21    mexa3t18_aggress
# 48  detoxis21_aggressiveness                    haha21        meoffendes21
# 49  detoxis21_aggressiveness                   exist21              haha21
# 50                davincis22                    haha21        meoffendes21
# 51                davincis22  detoxis21_aggressiveness             exist21
# 52                davincis22  detoxis21_aggressiveness             exist21
# 53                    haha21        misogyny_centrogeo                None
# 54                davincis22  detoxis21_aggressiveness              haha21
# 55                   exist21                    haha21        meoffendes21
# 56                davincis22                   exist21                None
# 57                davincis22  detoxis21_aggressiveness        meoffendes21
# 58                davincis22  detoxis21_aggressiveness                None
# 59                davincis22                   exist21              haha21
# 60                davincis22                   exist21              haha21
# 61                davincis22  detoxis21_aggressiveness             exist21
# 62                davincis22  detoxis21_aggressiveness        meoffendes21
# 63                davincis22                    haha21        meoffendes21
# 64                davincis22  detoxis21_aggressiveness        meoffendes21
# 65  detoxis21_aggressiveness          mexa3t18_aggress             metwo22
# 66                davincis22              meoffendes21                None
# 67                davincis22  detoxis21_aggressiveness              haha21
# 68                davincis22                    haha21    mexa3t18_aggress
# 69                davincis22                    haha21        meoffendes21
# 70                    haha21              meoffendes21    mexa3t18_aggress
# 71                davincis22  detoxis21_aggressiveness              haha21
# 72                   exist21              meoffendes21    mexa3t18_aggress
# 73                davincis22  detoxis21_aggressiveness              haha21
# 74                davincis22                    haha21        meoffendes21
# 75  detoxis21_aggressiveness                   exist21              haha21
# 76                davincis22  detoxis21_aggressiveness    mexa3t18_aggress
# 77                   exist21                    haha21        meoffendes21
# 78                davincis22                   exist21              haha21
# 79                   exist21              meoffendes21    mexa3t18_aggress
# 80                davincis22                       NaN                None
# 81  detoxis21_aggressiveness                       NaN                None
# 82                   exist21                       NaN                None
# 83                    haha21                       NaN                None
# 84              meoffendes21                       NaN                None
# 85          mexa3t18_aggress                       NaN                None
# 86        misogyny_centrogeo                       NaN                None
# 87                   metwo22                       NaN                None
# 88                      None                      None                None
#
#                      3                   4                   5  \
# 0                 None                None                None
# 1   misogyny_centrogeo             metwo22                None
# 2     mexa3t18_aggress             metwo22                None
# 3                 None                None                None
# 4                 None                None                None
# 5   misogyny_centrogeo                None                None
# 6                 None                None                None
# 7     mexa3t18_aggress                None                None
# 8     mexa3t18_aggress             metwo22                None
# 9              metwo22                None                None
# 10  misogyny_centrogeo             metwo22                None
# 11  misogyny_centrogeo             metwo22                None
# 12    mexa3t18_aggress             metwo22                None
# 13    mexa3t18_aggress  misogyny_centrogeo                None
# 14    mexa3t18_aggress                None                None
# 15                None                None                None
# 16  misogyny_centrogeo             metwo22                None
# 17                None                None                None
# 18        meoffendes21    mexa3t18_aggress                None
# 19                None                None                None
# 20                None                None                None
# 21                None                None                None
# 22        meoffendes21  misogyny_centrogeo             metwo22
# 23                None                None                None
# 24        meoffendes21    mexa3t18_aggress  misogyny_centrogeo
# 25        meoffendes21  misogyny_centrogeo                None
# 26             metwo22                None                None
# 27             metwo22                None                None
# 28             metwo22                None                None
# 29                None                None                None
# 30    mexa3t18_aggress  misogyny_centrogeo             metwo22
# 31    mexa3t18_aggress             metwo22                None
# 32  misogyny_centrogeo             metwo22                None
# 33    mexa3t18_aggress  misogyny_centrogeo                None
# 34  misogyny_centrogeo                None                None
# 35  misogyny_centrogeo             metwo22                None
# 36              haha21        meoffendes21             metwo22
# 37             metwo22                None                None
# 38  misogyny_centrogeo                None                None
# 39                None                None                None
# 40        meoffendes21  misogyny_centrogeo             metwo22
# 41                None                None                None
# 42        meoffendes21    mexa3t18_aggress  misogyny_centrogeo
# 43                None                None                None
# 44    mexa3t18_aggress  misogyny_centrogeo                None
# 45                None                None                None
# 46        meoffendes21  misogyny_centrogeo                None
# 47             metwo22                None                None
# 48             metwo22                None                None
# 49    mexa3t18_aggress  misogyny_centrogeo             metwo22
# 50    mexa3t18_aggress  misogyny_centrogeo                None
# 51              haha21    mexa3t18_aggress             metwo22
# 52              haha21        meoffendes21    mexa3t18_aggress
# 53                None                None                None
# 54    mexa3t18_aggress             metwo22                None
# 55                None                None                None
# 56                None                None                None
# 57                None                None                None
# 58                None                None                None
# 59                None                None                None
# 60             metwo22                None                None
# 61             metwo22                None                None
# 62             metwo22                None                None
# 63    mexa3t18_aggress                None                None
# 64  misogyny_centrogeo                None                None
# 65                None                None                None
# 66                None                None                None
# 67        meoffendes21    mexa3t18_aggress  misogyny_centrogeo
# 68                None                None                None
# 69    mexa3t18_aggress  misogyny_centrogeo             metwo22
# 70  misogyny_centrogeo             metwo22                None
# 71    mexa3t18_aggress  misogyny_centrogeo                None
# 72  misogyny_centrogeo                None                None
# 73    mexa3t18_aggress                None                None
# 74             metwo22                None                None
# 75    mexa3t18_aggress             metwo22                None
# 76  misogyny_centrogeo             metwo22                None
# 77    mexa3t18_aggress  misogyny_centrogeo             metwo22
# 78  misogyny_centrogeo             metwo22                None
# 79             metwo22                None                None
# 80                None                None                None
# 81                None                None                None
# 82                None                None                None
# 83                None                None                None
# 84                None                None                None
# 85                None                None                None
# 86                None                None                None
# 87                None                None                None
# 88                None                None                None
#
#                      6
# 0                 None
# 1                 None
# 2                 None
# 3                 None
# 4                 None
# 5                 None
# 6                 None
# 7                 None
# 8                 None
# 9                 None
# 10                None
# 11                None
# 12                None
# 13                None
# 14                None
# 15                None
# 16                None
# 17                None
# 18                None
# 19                None
# 20                None
# 21                None
# 22                None
# 23                None
# 24             metwo22
# 25                None
# 26                None
# 27                None
# 28                None
# 29                None
# 30                None
# 31                None
# 32                None
# 33                None
# 34                None
# 35                None
# 36                None
# 37                None
# 38                None
# 39                None
# 40                None
# 41                None
# 42                None
# 43                None
# 44                None
# 45                None
# 46                None
# 47                None
# 48                None
# 49                None
# 50                None
# 51                None
# 52  misogyny_centrogeo
# 53                None
# 54                None
# 55                None
# 56                None
# 57                None
# 58                None
# 59                None
# 60                None
# 61                None
# 62                None
# 63                None
# 64                None
# 65                None
# 66                None
# 67             metwo22
# 68                None
# 69                None
# 70                None
# 71                None
# 72                None
# 73                None
# 74                None
# 75                None
# 76                None
# 77                None
# 78                None
# 79                None
# 80                None
# 81                None
# 82                None
# 83                None
# 84                None
# 85                None
# 86                None
# 87                None
# 88                None

# %%
# 17 Datasets
for i, fn in enumerate(glob("dataset_es/*_Es_train.json")):
    train_df = pd.read_json(fn, lines=True)
    test_df = pd.read_json(fn.replace("_train", "_test"), lines=True)
    ds_n = fn.replace("dataset_es\\",'').replace('_Es_train.json','')
    print(i, ds_n, train_df.shape, test_df.shape)
# Out:
# 0 davincis22 (2521, 2) (841, 2)
# 1 detoxis21_aggressiveness (2770, 2) (693, 2)
# 2 detoxis21_insult (2770, 2) (693, 2)
# 3 detoxis21_intolerance (2770, 2) (693, 2)
# 4 detoxis21_mockery (2770, 2) (693, 2)
# 5 detoxis21_sarcasm (2770, 2) (693, 2)
# 6 detoxis21_stereotype (2770, 2) (693, 2)
# 7 detoxis21_toxicity (2770, 2) (693, 2)
# 8 exist21 (2655, 2) (886, 2)
# 9 haha21 (18000, 2) (6000, 2)
# 10 meoffendes21 (3795, 2) (1265, 2)
# 11 metwo22 (2880, 2) (720, 2)
# 12 mexa3t18_aggress (5389, 5) (2311, 5)
# 13 misoginia (2645, 5) (662, 5)
# 14 misogyny_centrogeo (5752, 2) (1439, 2)
# 15 semeval2018_anger (1359, 6) (627, 6)
# 16 semeval2018_sadness (1350, 6) (641, 6)

# %%
# 17 Datasets
d = []
for i, fn in enumerate(glob("dataset_es/*_Es_train.json")):
    train_df = pd.read_json(fn, lines=True)
    test_df = pd.read_json(fn.replace("_train", "_test"), lines=True)
    ds_n = fn.replace("dataset_es\\",'').replace('_Es_train.json','')
    d.append({'dataset': ds_n, 'train_shape': train_df.shape, 'test_shape':test_df.shape})
df2 = pd.DataFrame(d)
df2.to_csv('dataset_shapes_17.csv')
df2
# Out:
#                      dataset train_shape test_shape
# 0                 davincis22   (2521, 2)   (841, 2)
# 1   detoxis21_aggressiveness   (2770, 2)   (693, 2)
# 2           detoxis21_insult   (2770, 2)   (693, 2)
# 3      detoxis21_intolerance   (2770, 2)   (693, 2)
# 4          detoxis21_mockery   (2770, 2)   (693, 2)
# 5          detoxis21_sarcasm   (2770, 2)   (693, 2)
# 6       detoxis21_stereotype   (2770, 2)   (693, 2)
# 7         detoxis21_toxicity   (2770, 2)   (693, 2)
# 8                    exist21   (2655, 2)   (886, 2)
# 9                     haha21  (18000, 2)  (6000, 2)
# 10              meoffendes21   (3795, 2)  (1265, 2)
# 11                   metwo22   (2880, 2)   (720, 2)
# 12          mexa3t18_aggress   (5389, 5)  (2311, 5)
# 13                 misoginia   (2645, 5)   (662, 5)
# 14        misogyny_centrogeo   (5752, 2)  (1439, 2)
# 15         semeval2018_anger   (1359, 6)   (627, 6)
# 16       semeval2018_sadness   (1350, 6)   (641, 6)

# %% [markdown]
# ---

# %%
print(pre_models_dict)
fnames = glob("dataset_es/meoffendes21_Es_train.json") ## todos los train datasets
fnames.sort()
for fn in fnames:
    print(fn)
    for i, sample in df_samples[:2].iterrows():
        ds_n = fn.replace("dataset_es\\",'').replace("dataset_es/",'').replace('_Es_train.json','')
        sample_avoid = sample.dropna().values[sample.dropna().values != ds_n]
        print(sample.dropna().values, sample_avoid)
# Out:
# {'davincis22': [<EvoMSA.base.EvoMSA object at 0x0000022E90513E80>, 'sklearn.svm.LinearSVC'], 'detoxis21_aggressiveness': [<EvoMSA.base.EvoMSA object at 0x0000022E905371C0>, 'sklearn.svm.LinearSVC'], 'exist21': [<EvoMSA.base.EvoMSA object at 0x0000022E90537CA0>, 'sklearn.svm.LinearSVC'], 'haha21': [<EvoMSA.base.EvoMSA object at 0x0000022E905374C0>, 'sklearn.svm.LinearSVC'], 'meoffendes21': [<EvoMSA.base.EvoMSA object at 0x0000022E90537280>, 'sklearn.svm.LinearSVC'], 'mexa3t18_aggress': [<EvoMSA.base.EvoMSA object at 0x0000022E90537670>, 'sklearn.svm.LinearSVC'], 'misogyny_centrogeo': [<EvoMSA.base.EvoMSA object at 0x0000022E9587E190>, 'sklearn.svm.LinearSVC'], 'metwo22': [<EvoMSA.base.EvoMSA object at 0x0000022E9587E340>, 'sklearn.svm.LinearSVC']}
# dataset_es/meoffendes21_Es_train.json
# ['haha21' 'meoffendes21'] ['haha21']
# ['exist21' 'misogyny_centrogeo' 'metwo22'] ['exist21' 'misogyny_centrogeo' 'metwo22']

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.options.display.max_rows = 1200
df1 = pd.read_csv('results_kfold.csv')
df2 = pd.read_csv('results_build_table_mms.csv')

df = pd.concat([df1, df2], ignore_index=True)
print(df1.shape, df2.shape, df.shape)

# %%
#df['dataset'] = df['dataset'].str.replace(r'dataset_es\\', '')
#df
# df = df.drop(df.columns[0], axis=1)
#df.rename(columns = {df.columns[0]:'Idx'}, inplace = True)
#df.drop('Idx', inplace=True, axis=1)
#df.fillna("", inplace=True)
df

# %%
df.to_csv('results_kfolds_mms.csv')

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.options.display.max_rows = 1200
df1 = pd.read_csv('results_full_54_keep.csv')
df2 = pd.read_csv('results_full_56_keep.csv')
df3 = pd.read_csv('results_full_57_keep.csv')
df4 = pd.read_csv('results_full_58_keep.csv')
df5 = pd.read_csv('results_full_59_keep.csv')
df6 = pd.read_csv('results_full_60_keep.csv')
df7 = pd.read_csv('results_full_61_keep.csv')
df8 = pd.read_csv('results_full_62_keep.csv')
df9 = pd.read_csv('results_full_63_keep.csv')
df10 = pd.read_csv('results_full_64_keep.csv')
df11 = pd.read_csv('results_full_65_keep.csv')
df12 = pd.read_csv('results_full_66_keep.csv')


df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12], ignore_index=True)
print(df1.shape, df2.shape, df.shape)

# %%
df.to_csv('results_full_17.csv')

# %%
df
